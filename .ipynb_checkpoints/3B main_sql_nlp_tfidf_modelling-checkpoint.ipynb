# %% [markdown]
# <h1>Part 3 : Modeling of Pre-processed Text Data</h1>

# %% [markdown]
# <h3>Import Packages</h3>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import os
import warnings
warnings.filterwarnings('ignore')

from nltk.tokenize import word_tokenize
from nltk.stem.porter import PorterStemmer
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, ENGLISH_STOP_WORDS

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_recall_fscore_support as score

# %% [markdown]
# <h3>Load Data</h3>

# %%
from sqlalchemy import create_engine, MetaData, Table, select

engine = create_engine("sqlite:///joblist.sqlite")
metadata = MetaData()
data = Table('data', metadata, autoload=True, autoload_with=engine)
stmt = select([data.columns.jobdescription, data.columns.label])
connection = engine.connect()
results = connection.execute(stmt).fetchall()

df_data = pd.DataFrame(results)
df_data.columns = results[0].keys()
df_data['jobdescription'] = df_data['jobdescription'].astype('string').replace('\n', ' ')

# %%
df_data.head()
# Out:
#                                       jobdescription  label
# 0  Position Title:Pricing Analyst Position Type: ...      0
# 1  Title: Senior Data Analyst - Telephony Manager...      0
# 2  We are looking for a talented Fuel Cell Data E...      0
# 3  CAREER OPPORTUNITY SENIOR METER DATA ANALYST L...      0
# 4  The Data Engineer reports directly to the Dire...      0

# %%
df_data['jobdescription']
# Out:
# 0      Position Title:Pricing Analyst Position Type: ...
# 1      Title: Senior Data Analyst - Telephony Manager...
# 2      We are looking for a talented Fuel Cell Data E...
# 3      CAREER OPPORTUNITY SENIOR METER DATA ANALYST L...
# 4      The Data Engineer reports directly to the Dire...
#                              ...
# 620    While people dream of a better energy future, ...
# 621    Yelp has hundreds of millions of pieces of use...
# 622    #TeamNextdoor
#
# Nextdoor is the neighborhood hu...
# 623    Company Description
# Hi there! We’re Razorfish....
# 624    Auto req ID: 230021BR
#
# Job Description
# Sr. Man...
# Name: jobdescription, Length: 625, dtype: string

# %%
df_data['jobdescription'].values
# Out:
# <StringArray>
# [                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     "Position Title:Pricing Analyst Position Type: Temporary - Part-Time Requisition ID: 7304 Company: Day & Ross Inc. At Day & Ross, you’ll go far. Day & Ross is one of Canada’s largest transportation companies, serving top brands across North America. We got our start hauling potatoes in 1950, and now we have a team of more than 8 ...
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  'CAREER OPPORTUNITY SENIOR METER DATA ANALYST Location: Mississauga, ON If you are an ambitious, curious, hard-working, and seasoned energy professional, this is an exciting new opportunity for you to join the Rodan Energy team – an organization that has been recognized as one of Canada’s Top Small & Medium Employers for three years in a row. Rodan Energy is a top North American energy services company, quickly growing to serve our clients across North America. We are a leader in distributed energy resource asset optimization, demand response, energy management and intelligence systems, and power systems engineering and metering services. Our innovative solutions are designed for large commercial and industrial energy users as well as power  ...
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        'The Data Engineer reports directly to the Director, Business Intelligence & Analytics, and is responsible for the creation and implementation of business intelligence solutions. They will act as a subject matter expert (SME) for the design, development and maintenance of the data pipeline and storage requirements as they relate to the needs of the organization. This person works across functional areas to ensure quality and consistency in services.   The role also involves a consultative aspect by acting as a Subject Matter Expert (SME) for internal business units and customers. Key Responsibilities Act as a subject matter expert (SME) for data storage requirements as they relate to the needs of the organization. Design and Develop ET ...
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            "Join our Team We are seeking a highly motivated self-starter to join our fast-paced high-performing B2B Systems Capabilities team!  Reporting to the Manager, B2B Systems Capabilities, Strategy & Roadmap you will support the ideation, evaluation, and prioritization of the system capabilities backlog for our Salesforce and ServiceNow platforms. Our key mandate is to represent the Business stakeholders a ...
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       'Canadian Orthodontic Partners has an exciting new opportunity, looking for a talented new Analyst to join our Standards team! Reporting to the National Manager of COP Standards, the Business Analyst will gather and interpret data to develop actionab ...
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           'Address: 250 Yonge Street Job Family Group: Technology Liaises with stakeholders to understand problems and opportunities and, recommends solutions to enable the achievement of organizational goals. Builds exceptional relationships with business partners and internal stakeholders. Analyzes data and creates documents and plans in service of informing, advising, or updating stakeholders. Ensures the requirements map to a real business need, are approved by all relevant stakeholders, and meet essential quality standards. Participates in reviews or inspections, in collaboration with the project team, to ensure the quality of work products. Supports the execution of strategic initiatives in collaboration with internal and external stakeholders. Builds effective relationships with internal/external stakeholders. Leads or participates in defining the communication plan designed to positively influence or change behaviour; develops tailored messaging; and idetifies appropriate distribution channels. Works with project stakeholders to validate their requirements and analysis models via techniques such as reviews and walkthroughs. Ensures system specifications meet expectations/requirements, and negotiates solutions. Creates documentation to ensure the supportability of analyses. Maintains existing requirements to ensure that current-state needs are known. Develops and implements data collection systems and other strategies that optimize statistical efficiency and data quality. Identifies, analyzes, and interprets trends or patterns in complex data sets. Filters and “cleans” data, and reviews computer reports, printouts and performance indicators to locate and correct code problems. Remains alert to new techniques for insights, analytics, and data visualization, and devises new ways of applying them. Interprets data, analyzes results using statistical techniques and provide ongoing reports. Recommends approaches to st ...
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            'Company Description Are You Looking for a Great Place to Work? #Jointhegame Leader in the development and publishing of mobile games, Gameloft® has established itself as one of the top innovators in its field since 2000. Gameloft creates games for all digital platforms, two of which are featured in the “Top 10 Games by All-Time Worldwide Downloads” from App Annie. Gameloft operates its own established franchises such ...
#  ...
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              "Requisition ID: 97087\n\nJoin the Global Community of Scotiabankers to help customers become better off.\nPurpose:\nContributes to the overall success of the Scotia’s Digital Sales performance in Canada ensuring specific individual goals, plans, initiatives are executed / delivered in support of the team’s business strategies and objectives. Ensures all activities conducted are in compliance with governing regulations, internal policies and procedures.\nMajor Accountabilities:\nConducting advanced analytics to recommend strategies with our Digital Marketing partners generating sales revenue via digital channels.\nUsing Machine Learning and data science techniques to analysis massive volumes of structured and unstructured data to create actionable insights.\nContributing to the development of data driven Multi-touch attribution models\nIdentifying information gaps across business lines to drive alignment on key metrics; develop plan of action to address and close any gaps\nInvestigating and become an expert in available data sources of data, transform and determine how they can be interpreted for analysis\nSupport Campaign Management & Marketing Optimization by:\nCollaborating with Digital Marketing partners to enhance campaign performance and Return on Investment, including measuring application conversion, offer response rates, performing cost-benefit analysis, etc.\nIdentifying and articulating business insights that will inform strategic and tactical plans\nEnabling accurate digital data capture and analysis with Adobe and GA tools\nBeing involved in the definition of business requirements and processes, ensuring that progress can be measured against planned objectives by working with QA Development teams, Security, and internal partners; performing analysis and completing reports to measure project success and impact to business\nManage reporting and analytics for Digital Banking partners\nCollaborate with business stakeholders and technical partners to establish trends, understand performance, identify opportunities for growth, and provide a ...
# ...
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           "#TeamNextdoor\n\nNextdoor is the neighborhood hub for you, your neighbors, and the broader local community. Nextdoor's purpose is to cultivate a kinder world where everyone has a neighborhood they can rely on.\n\nReal-world connections are a universal human need and neighborhoods are one of the most important contexts in which we form them. This is a guiding principle for Nextdoor. Today, neighbors rely on Nextdoor in neighborhoods around the world in the United States, the United Kingdom, Germany, France, the Netherlands, Italy, Spain, Sweden, Denmark, Australia and Canada, with many more to come.\n\nMeet your Future Neighbors\n\nThe Data Science team at Nextdoor is part of the Data org, which also includes Business Intelligence and Data Engineering. At a high level, the Data org is responsible for the building and maintenance of data infrastructure as well as the use of that infrastructure for internal reporting, analysis, and modeling. Data Science at Nextdoor is responsible for design and oversight of product experiments, analysis and modeling to drive company and product strategy, and, where applicable, the deployment of online and offline models to a production environment. We use ...
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
#  "Auto req ID: 230021BR\n\nJob Description\nSr. Manager Advanced Analytics, Transformation & Strategy\n\n\nLocation: Remote working location within Canada\n\n\nThe Role:\n\nWe are a growing team focused on accelerating consumer demand, strengthening customer partnership and driving end to end productivity through data science and advanced analytics. We work with Shopper Insights, Shopper Marketing, Category Leadership, Supply Chain and IT resources to unlock opportunities. Being embedded in the business and linked to the top strategic priorities allows us to build best-in-class capabilities, develop deep functional expertise, and offer focused products in an agile responsive manner. Your analysis will be used to create new strategies and apply new analytical processes that will be shared with internal PepsiCo teams as well as with retailers.\n\n\nAs the leader of the Advanced Analytics team you will have the opportunity to shape our analytical services and operating model, partner with top executives to identify, investigate and provide insights to the organization while mentoring a highly skilled team. Through user groups and education, you have an opportunity to elevate the thinking and capabilities across the Canadian division, nurturing an analytical mindset.\n\n\nThis individual will operate in cross-functional teams to drive strategic advantage through more in-depth analysis of structured, semi-structured and unstructured data. This individual will be someone with an inherent passion for data and data driven thinking, adept at extracting actionable insights from volumes of data to drive strategy and operational efficiencies. Additionally, they will be tasked with building new predictive science capabilities and greater utilization to drive predictive and prescriptive actions rather than reactive behaviors to advance the business. This individual will be a combination of a data scientist and a business strategist; someone with an inherent passion for building and applying data science to problems, but, with a bias towards action and implementation.\n\n\nThe Company\n\nPepsiCo Canada is recognized as one of Canada’s top 100 employers. PepsiCo products are enjoyed by consumers more than one billion times a day in more than 200 countries and territories around the world. Our product portfolio includes 22 world-famous, billion-dollar brands; from Gatorade to Quaker, Tropicana to Lay’s and more. We make hundreds of enjoyable foods and beverages that are loved throughout the world. PepsiCo's effort to help build a more sustainable food system represents a key element of the company's broader vision of accelerated, sustainable growth known as Winning with Purpose. As part of this vision, PepsiCo is striving to be a better company by further integrating purpose into the core of its business and brands and doing even more for people and the planet. Our purpose efforts include fostering a diverse and inclusive work environment, supporting the communities where we live and work, and improving choices in our portfolio through reformulations and new products.\n\n\nAt PepsiCo Canada, we are focused on delighting our consumers by delivering high-quality products and exciting brand campaigns. Our people are critical to our success and by supporting their personal growth and development and providing them with the tools they need to succeed, PepsiCo Canada is a company you’ll be proud to join!\n\n\n\nWhat you’ll be working on:\nLead PepsiCo Foods Canada (PFC) advanced analytics team\nDefine advanced analytics strategy and prioritization framework for use cases\nIdentify analytical capabilities and data gaps and how to fill those gaps\nCreate and execute advanced analytics rollout plan for PFC\nLead the development and deployment of analytical tools and data science techniques to create actionable insights by analyzing large data sets and developing custom solutions to uncover trends, patterns and insights in the data\nLead business strate ...
# Length: 625, dtype: string

# %% [raw]
# from nltk.stem.porter import PorterStemmer
#
# stem = PorterStemmer()
# df_data['jobdescription'].values.apply(stem)

# %% [markdown]
# <h2>Pre-Processing Steps</h2>
#
# <h3>Feature Extraction Using TF-IDF Vectorization</h3>

# %%
#custom_stopwords = ['bachelor', 'degree', 'work', 'equal', 'opportunity', 'employer', 'objectives', 'ontario', 'canada', 'disability', 'strong', 'including', 'ensure', 'understanding', 'related']

# %%
#nltk.download('stopwords')
from nltk.corpus import stopwords

# Initialize TFIDF Vectorizer
tvec = TfidfVectorizer(analyzer = 'word',  
                       stop_words = ENGLISH_STOP_WORDS.union(stopwords.words('french')), 
                       lowercase= True, 
                       min_df=4, 
                       #max_df = 0.95,
                      ngram_range = (1,3))

def preproc_text(txt):
    x = tvec.fit_transform(txt) # Apply Vectorizer, Stopword Removal, & Lowercasing
    x
    return x

# %% [raw]
# # Initialize TFIDF Vectorizer
# tvec1 = TfidfVectorizer(analyzer = 'word',
#                        stop_words = ENGLISH_STOP_WORDS.union(stopwords.words(french)),
#                        lowercase= True,
#                        min_df=4)
#
# def tfidf1_pipeline(txt):
#     x = tvec1.fit_transform(txt) # Apply Vectorizer, Stopword Removal, & Lowercasing
#     return x

# %%
#counts = pd.DataFrame(.toarray(), columns = tvec.get_feature_names())
#counts.head()

# %% [markdown]
# <h3>Create Train & Test Sets</h3>

# %%
# Create a training and testing data sets
x_train, x_test, y_train, y_test = train_test_split(df_data['jobdescription'].values,df_data['label'],test_size=0.20, random_state=123, stratify=df_data['label'])

# %%
x_train
# Out:
# <StringArray>
# [                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           'Role Description:\nThe Messaging Specialist will be a key member of a national team supporting various customers . They will be responsible for Operation, health, function, patching, enhancement delivery, data analysis, trending, incident response, security, compliance, governance, documentation and supporting critical initiatives on the messaging platforms of customers.\n\nObjectives include:\n\nExecute on the overall administration of customer messaging environments, including maintaining environment health and functionality, troubleshooting, problem management, account management, and monitoring.\nMaintaining a deep and current understanding of cloud technologies and collaboration tools such as O365, Teams, Exchange, Exchange Online, OneDrive, Intune, Azure AD, business analytics. Serves as an advisor in the assessment, planning and implementation of new features and capabilities.\nGather and document requirements from stakeholders for messaging environments including Exchange, Exchange Online, Gmail Enterprise and others. Integrate or align processes to meet the governance objectives of the stakeholder community.\nSupport management team with analysis and communication materials related to operational activities.\n\nThe following is expected of the Advanced Support Analyst:\n\nExcellent communication skills (written and oral)\nChange management/business transformation experience\nExperience with the development of process and work flow engineering, design and implementation\nUnderstanding, and experience with, IT Operations and delivery of service\nExperience facilitating and managing consultation and requirements gathering with a wide range of stakeholders\nDemonstrated ability to develop positive relationships with business and technical stakeholders: enabling and supporting successful project and/or strategy delivery\nExperience in Oil & Gas industry, strategy and implementations\n\nResponsibilities and Deliverables\n\n\nAct as a senior administrator for customer messaging environments and coach junior team members\nFacilitates requirements gathering sessions with technical and business stakeholders\nDesign, construct and maintain all facets of messaging solutions\nPlan and Execute an end-to-end implementation of the target workloads\nMaintain a thorough understanding of existing and emerging Office 365 and related core technologies and administration such as Microsoft Endpoint Manager ...
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               "Req Id: 278054\nAt Bell, we do more than build world-class networks, develop innovative services and create original multiplatform media content – we advance how Canadians connect with each other and the world.\nIf you’re ready to bring game-changing ideas to life and join a community that values, professional growth and employee wellness, we want you on the Bell team.\nBell is making unmatched investments in our world-leading broadband fibre and wireless networks because we know they’re the backbone of the products and services our customers love. If you’re excited about transforming the way people connect, our Network team is the right place for you.\nOur Network of the future is adaptable, scalable, and fully automated. As network demand is growing exponentially and as we need to accelerate the pace at which we deliver the next generation 5G services to our customers, advanced orchestration, machine learning, and artificial intelligence become more and more critical. Every day is a new opportunity to experience new technology and develop new capabilities for our customers and internal operations. We are looking for a leader who will help us build our future.\nThe Wireless Network Orchestration & data insights team is responsible for developing and operating automation, orchestration, analytics and AI initiatives to transform the way we run Bell’s 5G and 4G Networks. Our team’s mission: to build an autonomous wireless network.\nThis is a unique opportunity to be part of a dynamic and innovative team.\nThe Role\nWithin Bell’s Wireless Network Orchestration & data insights team, the Senior Manager, Wireless Network Intelligence & Analytics Solutions is responsible for leading and supporting a team of software developers, business analysts, data engineers and data scientists to develop and maintain performance & capacity analytics, dashboarding/ reporting, and machine learning solutions used to improve reliability in specific areas of our wireless network.\nThe successful candidate will have the right mix of skills and experience in software development, data analytics, machine learning and people leadership.\nIn this role, you will have the opportunity to:\nLead a team – You will be accountable for the full delivery and operations of analytics solutions for specific areas of our wireless network. You will lead a cross-functional team of architects, developers, data engineers and data scientists in an agile environment to deliver best in class analytics solutions.\nDevelop a team - Grow your team to respond to increasing demand for advanced analytics & AI.\nLearn & Innovate – Be at the forefront of innovation. Work with a team of experts on leading edge technologies in order to deliver the highest business impact.\nDrive results – Use and develop your business skills to understand and deliver the highest business impact\n Main Responsibilities\nEstablish strategy, deliver and operate performance & capacity analytics, dashboa ...
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                "Are you a kid at heart looking to build a career with a leading global children's toy, entertainment and digital gaming company? At Spin Master, our unwavering commitment to open mindedness, integrity and innovation is a great part of what has made us an industry leader. How do we stay ahead of the pack? By hiring the best and brightest minds—and that’s why we want you! Job Description: What will you work on? As the e-Commerce Merchandise Analyst, you will support Spin Master’s online growth within the US and Canada with a focus on Marketplace, Mid-Tier US accounts and Canada (ie. Amazon, Walmart. and Toys R Us). Your focus is to deliver best in class EComm experiences across sites, partnering with sales, supply chain, COE’s and brands team ensure timely publishing of all items and accountability for complete and accurate product information. You thrive in a fast-paced environment and are relentless at testing and learning to drive share of voice, rankings and ultimately sales. Ultimately your goal will be to ensure each of your online retailers provide a great consumer experience, while supporting our sales and brand objectives.  How will you create impact? Work with sales and brand teams to support seasonal and annual growth plans. Provide support to develop, standardise, and execute the best in class e-commerce executions in collaboration with colleagues from sales, marketing and COE teams. Work with both internal and external cross-functional teams to ensure all content is pushed, complete and ready to be received by the retailer in conjunction with inventory being received or launch date. Work with translations team to ensure content is proactively created and loaded into Salsify Execute Item set-up in each online retailers’ platform. Submit and manage assets through each online retailers’ platform. Ensure accurate representation and communication of  ...
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             'Data Analyst, SAP 2 Lansing Square, North York, ON M2J 4P8, Canada Req #952  Monday, March 1, 2021 To support our continued growth and provide excellence in customer service and satisfaction, Reliance Home Comfort is looking for a high energy and results focused individual for the following role: To support our continued growth, we are looking for a high energy, results focused individual for the following role: Position: SAP Data Analyst (12-month Contract) Location: 2 Lansing Square, Toronto Reports to: Project Leader, CIS System Implementation Company Overview: For the past 50 years, Reliance Home Comfort has been the industry leader in providing home comfort solutions to over 1.9 million customers across North America.  Reliance™ has been providing affordable, reliable home heating, cooling, hot water, water purification, electrical, plumbing & Smart Home products & services. Our customers know they can count on us for fast, friendly, knowledgeable service and advice – and that’s comfortable!  Our organization has grown exponentially in size and we are incredibly proud to be recognized recently by:  Waterstone Human Capital Ltd. as Canada’s 10 Most Admired Corporate Cultures Waterstone Human Capital Ltd. for Canada’s Most Admired CEO (Sean O’Brien) Glassdoor as “Best Places to Work in Canada”  Each day, 2,300 Reliance Team Members focus on delivering an outstanding customer experience, developing top talent and giving back to the communities where we live and work. In 2019 alone, we have donated over $650,000 to United Way and $100,000 in equipment to Habitat for Humanity. Primary Mission: Role requires an engaged, organized, and a self-starter-type individual with strong data cleansing and migration skills. This individual will be responsible for supporting the Reliance Data Workstream and Business Solution Integration leads. This is a cross functional SAP data role which provides data cleansing, data migration, solution testing, data cutover support. Key Responsibilities:  Responsible for working with Business data lead and SAP technical migration lead to develop a data cleansing and migration strategy, execute data cleansing and migration project activities, and perform data conversion during mock conversions, cutover, and go-live phases. Support Reliance data workstream in developing a data governance strategy that includes business metadata definition, data quality measures, and data controls definition. Leverage SAP data migration methodologies and migration tools to execute data migration activities for data extraction, transformation to SAP S/4HANA target, load and validation activities. Bring a business lens to the data workstream required to understand the nature of legacy data elements. Standardize and simplify Reliance data definitions and content to migrate into an SAP S/4HANA master ...
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      'Address: 250 Yonge Street Job Family Group: Technology Liaises with stakeholders to understand problems and opportunities and, recommends solutions to enable the achievement of organizational goals. Builds exceptional relationships with business partners and internal stakeholders. Analyzes data and creates documents and plans in service of informing, advising, or updating stakeholders. Ensures the requirements map to a real business need, are approved by all relevant stakeholders, and meet essential quality standards. Participates in reviews or inspections, in collaboration with the project team, to ensure the quality of work products. Supports the execution of strategic initiatives in collaboration with internal and external stakeholders. Builds effective relationships with internal/external stakeholders. Leads or participates in defining the communication plan designed to positively influence or change behaviour; develops tailored messaging; and idetifies appropriate distribution channels. Works with project stakeholders to validate their requirements and analysis models via techniques such as reviews and walkthroughs. Ensures system specifications meet expectations/requirements, and negotiates solutions. Creates documentation to ensure the supportability of analyses. Maintains existing requirements to ensure that current-state needs are known. Develops and implements data collection systems and other strategies that optimize statistical efficiency and data quality. Identifies, analyzes, and interprets trends or patterns in complex data sets. Filters and “cleans” data, and reviews computer reports, printouts and performance indicators to locate ...
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              "Adresse : 234 Simcoe Street Groupe de famille d'emploi : Analyses données et rapports Creates a culture where data is managed as a valuable corporate asset. Provides input to, and follows, data governance standards and processes to improve the quality of BMO data and reduce overall data risk for the designated business/group. Develops and implements data strategies, tactics, products and a curated data model to achieve business objectives. Reviews, designs and implements data governance practices and data management processes within the business/group in alignment with Enterprise Data Governance Operating Directive. Provides guidance on the interpretation of enterprise data governance policies and maintains alignment between data governance practices and the data strategy. Develops data solutions and makes recommendations based on an understanding of the business strategy and stakeholder needs. Supports the assessment, root cause analysis, and formulating proposed solutions/remediation strategies. Performs data profiling and data analyses. Documents and maintains data flow specifications. Conducts needs assessments, identifies gaps and provides suggestions to improve and streamline data management processes based on operational insights. Contributes to the development of business/group data strategies and data governance policies, procedures, and processes. Develops stakeholder communications and training in support of data management process implementation. Supports the resolution of data issues by coordinating stakeholders in the information chain. Performs quality assurance activities to ensure handling, storage, and collection of data complies with Bank Policy and regulatory requirements. Supports the management of BMO’s data as a key asset that facilitates effective decision making. Analyzes structured and unstructured data to support the design and development of a business / group curated data model. Provides advice and guidance to assigned business/group on implementation of data solutions. Identifies and implements the optimum means to c ...
#  ...
#  "You are as unique as your background, experience and point of view. Here, you’ll be encouraged, empowered and challenged to be your best self. You'll work with dynamic colleagues - experts in their fields - who are eager to share their knowledge with you. Your leaders will inspire and help you reach your potential and soar to new heights. Every day, you'll have new and exciting opportunities to make life brighter for our Clients - who are at the heart of everything we do. Discover how you can make a difference in the lives of individuals, families and communities around the world. Job Description: Role Summary Be part of an exciting and challenging opportunity by helping to accelerate the growth and application of data analytics capabilities at Sun Life Canada. As part of the Distribution Analytics team within Sun Life Canada's Individual Insurance & Wealth line of business, you will have an opportunity to be at the forefront of applying data and analytics to tackle business problems. As well, helping Sun Life use analytics to deliver on our purpose of helping our Clients achieve lifetime financial security and live healthier lives. As a Distribution Data Analyst, your focus will be working with a team of analytics professionals and other partners to source, manipulate, and transform data, develop enhanced reporting, produce innovative and effective analyses of data, contribute to an ethical and robustly managed best-practice team environment, and, most importantly, drive impact that matters to shareholders, employees, advisors, and Clients. Given the mandate of the role, the Distribution Data Analyst must be an individual with 2 -3 years experience, who possesses a breadth of analytical and data skills. The Candidate must have proven experience and ability in the following areas: Data sourcing, manipulation, and transformation Insightful analysis of data Critical thinking skills and the ability to think outside the box to resolve issues Fierce curiosity. You are drawn to discovering and leveraging new data and taking on challenging business puzzles. Understanding business. We’ve got a lot of data, but it’s not going to turn itself into insights, and you can’t help with that unless you understand what the numbers mean. A passion for solving problems. The most successful data analysts don’t just spin data and give numbers, they solve the problem. Technical skills. How to wrangle structured data is a must (i.e., SQL) with strong excel skills needed currently and the opportunity to move to other analytical tools (SAS, R, Python etc) as the role matures. What will you do? Data Sourcing, Manipulation, and Transformation (40%) Become an expert on Sun Life client and advisor data, and be knowledgeable of applicable 3rd party data Develop a strong knowledge of quantitative data mining tools and techniques Effectively translate business and project needs into data extraction and manipulation plans Source, extract, clean, and transform data to meet project plan needs Insightful Analysis of Data (40%) Conduct analyses that identify / assess business opportunities and address key business challenges Identify, verify, evaluate, and validate hidden patterns in client and advisor data Work with partners to assist in development of predictive models Enable leaders to make timely data-driven product, market-development, and distribution decisions Effectively translate business problems into analysis problems Reporting & Business Intelligence (20%) Prepare / compile ongoing trend reporting as required, daily, weekly, and monthly Implement and report on performance metrics to support initiative measurement, analysis, and reporting, and measure effectiveness of predictive modelling efforts Work within the Distribution Analytics team to develop process improvements, with a focus on increasing efficiency, effectiveness, and controls What will you need to succeed? Coding & Technical Skills Proven experience with a subset of SAS, SQL, Excel, VBA, P ...
# ...
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             "Requisition ID: 97894  Join the Global Community of Scotiabankers to help customers become better off. As part of the Procurement Operations team, the RFx Management Analyst executes operational activities that support the set-up of RFx events in the Bank’s procurement technology application. Reporting to the RFx Management Manager, this position provides support assistance to Sourcing Managers, Evaluators and 3rd parties during the running of RFx events and with general questions. This role is responsible to follow and execute the RFx procedures to ensure Operational Level Agreement targets are met. Work is performed in accordance with the Scotiabank values and guiding principles, and in adherence to the Scotiabank Code of Conduct. What you'll do in this role? Champion a customer focused culture to deepen client relationships and leverage broader Bank relationships, systems and knowledge.Operate the Bank’s procurement technology solutions for setting up RFx events, based on Sourcing Manager specifications.Interact with Sourcing Managers to support RFx events including: training, live monit ...
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     "As a leading mobile games developer, Jam City is looking to “level up” our talent for our Bingo team in Toronto. We’re on the hunt for innovators who consider themselves dynamic, collaborative and thrive in a fast-paced environment.  PERKS & BENEFITS Unlimited Vacation, Paid Sick Days & Holidays* 100% Employee Covered Medical, Dental, Vision Plan Base Plan* Life Insurance, RRSP matching, Flexible Spending Accounts & More* Catered Lunches & Well-stocked Kitchens Company Events such as movie night, pub night and more… You'll be equipped with a high-end laptop, monitor and mobile device Convenient location in downtown Toronto’s entertainment and technology districtOnly applies to full-time positions. ABOUT THE ROLE We’re currently looking for a passionate Senior Data Analyst who loves data and has a great mind for surfacing insightful visualizations of their research. You will have the opportunity to collaborate with some of the top creative and analytical talent in a highly profitable mobile game development studio with an array of perks and respect for employee quality of life and personal time. RESPONSIBILITIES Formulates and leads guided, multifaceted analytic studies against large volumes of data. Interprets and analyzes data using exploratory mathematic and statistical techniques based on the scientific method. Coordinates research and analytic activities utilizing various data points (unstructured and structured) and employ programming to clean, massage, and organize the data. Experiments against data points, provide information based on experiment results and provide previously undiscovered solutions to command data challenges. Work with business leaders to identify and define analytical requirements for teams and projects. Using multiple data sources, create reporting and performance monitoring tools and dashboards for end users. Understand and effectively communicate trends and analysis on user behavior, player segmentation, virality, and marketing campaigns. Continuously develop thorough analysis and conclusive insights that drive  ...
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# Length: 500, dtype: string

# %%
x_train[309]
# Out:
# "Adresse : 234 Simcoe Street Groupe de famille d'emploi : Analyses données et rapports Creates a culture where data is managed as a valuable corporate asset. Provides input to, and follows, data governance standards and processes to improve the quality of BMO data and reduce overall data risk for the designated business/group. Develops and implements data strategies, tactics, products and a curated data model to achieve business objectives. Reviews, designs and implements data governance practices and data management processes within the business/group in alignment with Enterprise Data Governance Operating Directive. Provides guidance on the interpretation of enterprise data governance policies and maintains alignment between data governance practices and the data strategy. Develops data solutions and makes recommendations based on an understanding of the business strategy and stakeholder needs. Supports the assessment, root cause analysis, and formulating proposed solutions/remediation strategies. Performs data profiling and data analyses. Documents and maintains data flow specifications. Conducts needs assessments, identifies gaps and provides suggestions to improve and streamline data management processes based on operational insights. Contributes to the development of business/group data strategies and data governance policies, procedures, and processes. Develops stakeholder communications and training in support of data management process implementation. Supports the resolution of data issues by coordinating stakeholders in the information chain. Performs quality assurance activities to ensure handling, storage, and collection of data complies with Bank Policy and regulatory requirements. Supports the management of BMO’s data as a key asset that facilitates effective decision making. Analyzes structured and unstructured data to support the design and development of a business / group curated data model. Provides advice and guidance to assigned business/group on implementation of data solutions. Identifies and implements the optimum means to collect, process, analyze and report on information and ensure ongoing accuracy, integrity and security. Participates in the timely resolution of operating/technical problems or manages escalation with other BMO technical support groups. Assists in the identification of change impacts through requirements gathering, mapping and documenting current and proposed processes. Provides support to projects and/or manages operational changes including supporting Technology with the validation and testing of systems. Breaks down strategic problems, and analyses data and information to provide insights and recommendations. Builds effective relationships with internal/external stakeholders and ensures alignment. Supports development and execution of strategic initiatives in collaboration with internal and external stakeholders. Focus is primarily on Finance and Enterprise Risk Management. Exercises judgment to identify, diagnose, and solve problems within given rules. Works independently on a range of complex tasks, which may include unique situations. Broader work or accountabilities may be assigned as needed. Qualifications: Typically between 1 - 4 years of relevant experience and post-secondary degree in related field of study or an equivalent combination of education and experience. Skilled in database environments (e.g. Hadoop, Netezza, Oracle). Skilled in working with BI tools such as PowerBI, relational databases and Hadoop-based data mining frameworks. Proficient in working with SQL Technical proficiency gained through education and/or business experience. Verbal & written communication skills - In-depth. Collaboration & team skills - In-depth. Analytical and problem solving skills - In-depth. Influence skills - In-depth. Data driven decision making - In-depth. Ici, pour vous. À BMO, nous sommes animés par une raison d’être commune : Avoir le cran de faire une différence dans la vie, comm ...

# %%
print("Shape of y_test: ", y_test.shape)
# Out:
# Shape of y_test:  (125,)

# %% [markdown]
# <h3>Apply Pre-Processing Steps to Extract Features</h3>

# %%
x_train_TFIDF = tfidf_pipeline(x_train)
x_test_TFIDF = tfidf_pipeline(x_test)

# %% [raw]
# # Apply pre-processing
# # Unigrams
# x_train_TFIDF1 = tfidf_pipeline(x_train)
# x_test_TFIDF1 = tfidf_pipeline(x_test)

# %% [raw]
# # Apply pre-processing
# x_train_TFIDF2 = tfidf2_pipeline(x_train)
# x_test_TFIDF2 = tfidf2_pipeline(x_test)

# %%
print("Original training set shape: ", x_train.shape)
print("Preprocessed training set for unigrams: ", x_train_TFIDF.shape)
print("Preprocessed training set for n-grams: ", x_train_TFIDF.shape)

# %% [markdown]
# <h3>Modeling</h3>

# %%
# Initialize and fit Random Forest Classifier model
rfc = RandomForestClassifier(n_estimators=100, class_weight='balanced')
rfc_model = rfc.fit(x_train_TFIDF,y_train)

# %% [markdown]
# <h3>Cross-Validation</h3>

# %%
# %%timeit
# Apply 10-fold cross-validation
rfc_result = cross_val_score(rfc_model, x_train_TFIDF, y_train, cv=10, scoring='accuracy')
print("The mean of cross validation is: ", rfc_result.mean())

# %% [markdown]
# <h3>Evaluation on Test Data</h3>

# %%
# Predict y values using x train values
y_pred = rfc_model.predict(x_test_TFIDF)
precision, recall, fscore, support = score(y_test, 
                                            y_pred, 
                                            pos_label=1, 
                                            average ='binary')

print("Classification Report: \nPrecision: {}, \nRecall: {}, \nF-score: {}, \nAccuracy: {}".format(round(precision,3),round(recall,3),round(fscore,3),round((y_pred==y_test).sum()/len(y_test),3)))


# ValueError: Number of features of the model must match the input. 
# Model n_features is 6536 (x_train_TFIDF shape) and input n_features is 3213

# %%
# Confusion matrix
confusion_matrix(y_test, y_pred)
